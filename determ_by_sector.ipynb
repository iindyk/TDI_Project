# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('images/r_sq_by_sector.png')
fig, ax = plt.subplots(figsize=(90, 42))
ax.set_yticklabels([])
ax.set_xticklabels([])
ax.imshow(img)
plt.show()
